# %%
import matplotlib.pyplot as plt 
from tabulate import tabulate 
import matplotlib as mat 
import seaborn as sns 
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv(r"DS1_C6_S4_Credit_Data_Hackathon.csv")
df
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0          100002       1         Cash loans      M   N     Y             0
# 1          100003       0         Cash loans      F   N     N             0
# 2          100004       0    Revolving loans      M   Y     Y             0
# 3          100006       0         Cash loans      F   N     Y             0
# 4          100007       0         Cash loans      M   N     Y             0
# ...           ...     ...                ...    ...  ..   ...           ...
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
# ...

# %%
df.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0      100002       1         Cash loans      M   N     Y             0
# 1      100003       0         Cash loans      F   N     N             0
# 2      100004       0    Revolving loans      M   Y     Y             0
# 3      100006       0         Cash loans      F   N     Y             0
# 4      100007       0         Cash loans      M   N     Y             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... DAYS_EMPLOYED MOBILE  \
# 0          202500.0    406597.5         351000.0  ...          -637      1
# 1          270000.0   1293502.5        1129500.0  ...         -1188      1
# 2           67500.0    135000.0         135000.0  ...          -225      1
# 3          135000.0    312682.5         297000.0  ...         -3039      1
# 4          121500.0    513000.0         513000.0  ...         -3038      1
#
#   WORK_PHONE HOME_PHONE  MOBILE_REACHABLE  FLAG_EMAIL  OCCUPATION_TYPE  \
# ...

# %%
df.tail()
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
#        AMT_INCOME_TOTAL  AMT_CREDIT  AMT_GOODS_PRICE  ... DAYS_EMPLOYED  \
# 99995          157500.0    755190.0         675000.0  ...          -232
# 99996          225000.0    284400.0         225000.0  ...          -182
# 99997          135000.0   1262583.0        1102500.0  ...         -4805
# 99998          135000.0    225000.0         225000.0  ...          -340
# 99999          202500.0    337500.0         337500.0  ...         -3230
#
#       MOBILE WORK_PHONE HOME_PHONE  MOBILE_REACHABLE  FLAG_EMAIL  \
# ...

# %%
print(df.shape)
# Out:
# (100000, 24)

# %%
print(df.columns)
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'GENDER', 'Car', 'House',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'DAYS_EMPLOYED', 'MOBILE', 'WORK_PHONE',
#        'HOME_PHONE', 'MOBILE_REACHABLE', 'FLAG_EMAIL', 'OCCUPATION_TYPE',
#        'CNT_FAM_MEMBERS', 'APPLICATION_DAY', 'TOTAL_DOC_SUBMITTED'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 24 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   SK_ID_CURR           100000 non-null  int64
#  1   TARGET               100000 non-null  int64
#  2   NAME_CONTRACT_TYPE   100000 non-null  object
#  3   GENDER               100000 non-null  object
#  4   Car                  100000 non-null  object
#  5   House                100000 non-null  object
#  6   CNT_CHILDREN         100000 non-null  int64
#  7   AMT_INCOME_TOTAL     100000 non-null  float64
#  8   AMT_CREDIT           100000 non-null  float64
#  9   AMT_GOODS_PRICE      99919 non-null   float64
#  10  NAME_TYPE_SUITE      99595 non-null   object
#  11  NAME_INCOME_TYPE     100000 non-null  object
#  12  NAME_EDUCATION_TYPE  100000 non-null  object
#  13  NAME_FAMILY_STATUS   100000 non-null  object
#  14  DAYS_EMPLOYED        100000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# SK_ID_CURR                 0
# TARGET                     0
# NAME_CONTRACT_TYPE         0
# GENDER                     0
# Car                        0
# House                      0
# CNT_CHILDREN               0
# AMT_INCOME_TOTAL           0
# AMT_CREDIT                 0
# AMT_GOODS_PRICE           81
# NAME_TYPE_SUITE          405
# NAME_INCOME_TYPE           0
# NAME_EDUCATION_TYPE        0
# NAME_FAMILY_STATUS         0
# DAYS_EMPLOYED              0
# MOBILE                     0
# WORK_PHONE                 0
# HOME_PHONE                 0
# MOBILE_REACHABLE           0
# FLAG_EMAIL                 0
# OCCUPATION_TYPE        31224
# CNT_FAM_MEMBERS            1
# APPLICATION_DAY            0
# TOTAL_DOC_SUBMITTED        0
# dtype: int64

# %%
a=num_df=df.select_dtypes(exclude='object')
b=cat_df=df.select_dtypes(include='object')
print(tabulate({"Categorical":b,"Continuous":a},headers=['Categorical','Continuous']))
# Out:
# Categorical          Continuous
# -------------------  -------------------
# NAME_CONTRACT_TYPE   SK_ID_CURR
# GENDER               TARGET
# Car                  CNT_CHILDREN
# House                AMT_INCOME_TOTAL
# NAME_TYPE_SUITE      AMT_CREDIT
# NAME_INCOME_TYPE     AMT_GOODS_PRICE
# NAME_EDUCATION_TYPE  DAYS_EMPLOYED
# NAME_FAMILY_STATUS   MOBILE
# OCCUPATION_TYPE      WORK_PHONE
# APPLICATION_DAY      HOME_PHONE
#                      MOBILE_REACHABLE
#                      FLAG_EMAIL
#                      CNT_FAM_MEMBERS
#                      TOTAL_DOC_SUBMITTED

# %%
df['AMT_GOODS_PRICE'].mean()
# Out:
# 538345.1489706662

# %%
df['AMT_GOODS_PRICE ']=df['AMT_GOODS_PRICE'].fillna(538345.14897)

# %%
df["NAME_TYPE_SUITE"].mode()
# Out:
# 0    Unaccompanied
# Name: NAME_TYPE_SUITE, dtype: object

# %%
df["NAME_TYPE_SUITE"]=df['NAME_TYPE_SUITE'].fillna('Unaccompanied')

# %%
def info_of_cat(col): 
    print(f"Unique values in {col} are: {df[col].unique()}") # unique: returns the unique values in the col
    print(f"Mode of {col} is {df[col].mode()[0]}")  # mode: returns the mode of the column
    print(f"Number of missing values in {col} is {df[col].isnull().sum()}") # isnull().sum() counts the number of null in dataframe
    if df[col].isnull().sum() > 0:  # check if null values are present
        print(f"\nThere are null values in the {col} column")

# %% [markdown]
# # $$\;\;\;\;\;\;Univariate \ Analysis \ of \ Categorical \ Variables$$

# %%
info_of_cat("NAME_CONTRACT_TYPE") #function returns all the information required for the level 1 analysis
# Out:
# Unique values in NAME_CONTRACT_TYPE are: ['Cash loans' 'Revolving loans']
# Mode of NAME_CONTRACT_TYPE is Cash loans
# Number of missing values in NAME_CONTRACT_TYPE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of NAME_CONTRACT_TYPE")                  # Set the title of the graph
percentage = df["NAME_CONTRACT_TYPE"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["NAME_CONTRACT_TYPE"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["NAME_CONTRACT_TYPE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# # Interpretation= The majority of Name Contract Type is Cash Loans The Revolving Loans are very less then Cash Loans with the percentage of Cash Loans=90.52% and Revolving Loans=9.48%.

# %%
info_of_cat("GENDER") #function returns all the information required for the level 1 analysis
# Out:
# Unique values in GENDER are: ['M' 'F' 'XNA']
# Mode of GENDER is F
# Number of missing values in GENDER is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of GENDER")                  # Set the title of the graph
percentage = df["GENDER"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["GENDER"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["GENDER"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# # Interpretations= The majority count of gender is Females with the percentage of 65.86% and males are less with the percentage of 34.14%  XNA=0.00%.

# %%
info_of_cat("Car") #function returns all the information required for the level 1 analysis
# Out:
# Unique values in Car are: ['N' 'Y']
# Mode of Car is N
# Number of missing values in Car is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of Car")                  # Set the title of the graph
percentage = df["Car"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["Car"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["Car"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# # Interpretation=The majority of customers doesnt own a car 66.02% of customers doesnt have a car and only 33.98% customers owns a car.

# %%
info_of_cat("House") #function returns all the information required for the level 1 analysis
# Out:
# Unique values in House are: ['Y' 'N']
# Mode of House is Y
# Number of missing values in House is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of House")                  # Set the title of the graph
percentage = df["House"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["House"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["House"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# # Interpretation= Majority of customers have there own house the percentage of customers with houses are 69.33% and only 30.67% of customers doesnt have there own house.

# %%
info_of_cat("NAME_TYPE_SUITE") #function returns all the information required for the level 1 analysis
# Out:
# Unique values in NAME_TYPE_SUITE are: ['Unaccompanied' 'Family' 'Spouse, partner' 'Children' 'Other_A' 'Other_B'
#  'Group of people']
# Mode of NAME_TYPE_SUITE is Unaccompanied
# Number of missing values in NAME_TYPE_SUITE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of NAME_TYPE_SUITE")                  # Set the title of the graph
percentage = df["NAME_TYPE_SUITE"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["NAME_TYPE_SUITE"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["NAME_TYPE_SUITE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# # Interpretation= Majority of Name Type Suite are unaccompanied the percentage are 81.19%, 13.10% of customers acompannied with Family 3.70% are spouse partner. 1.07% are having childrens.

# %%
info_of_cat("NAME_INCOME_TYPE") #function returns all the information required for the level 1 analysis
# Out:
# Unique values in NAME_INCOME_TYPE are: ['Working' 'State servant' 'Commercial associate' 'Pensioner' 'Unemployed'
#  'Student' 'Businessman' 'Maternity leave']
# Mode of NAME_INCOME_TYPE is Working
# Number of missing values in NAME_INCOME_TYPE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of NAME_INCOME_TYPE")                  # Set the title of the graph
percentage = df["NAME_INCOME_TYPE"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["NAME_INCOME_TYPE"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["NAME_INCOME_TYPE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# # Interpretation= Majority of customers are having income by getting jobs with the percentage of 51.90%, and 17.86% of customers are having pension, 23.22% of customer are having comercial associates and 7.00% customers are State servant.

# %%
info_of_cat("NAME_EDUCATION_TYPE") #function returns all the information required for the level 1 analysis
# Out:
# Unique values in NAME_EDUCATION_TYPE are: ['Secondary / secondary special' 'Higher education' 'Incomplete higher'
#  'Lower secondary' 'Academic degree']
# Mode of NAME_EDUCATION_TYPE is Secondary / secondary special
# Number of missing values in NAME_EDUCATION_TYPE is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of NAME_EDUCATION_TYPE")                  # Set the title of the graph
percentage = df["NAME_EDUCATION_TYPE"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["NAME_EDUCATION_TYPE"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["NAME_EDUCATION_TYPE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# # Interpretation= Customers having Secondary/Secondary special are majorily there with the percentage of 71.07%, 24.40% of Higher education, 3.27% of customers incomplete Higher and Lower Secondary are 0.05%.

# %%
info_of_cat("NAME_FAMILY_STATUS") #function returns all the information required for the level 1 analysis
# Out:
# Unique values in NAME_FAMILY_STATUS are: ['Single / not married' 'Married' 'Civil marriage' 'Widow' 'Separated'
#  'Unknown']
# Mode of NAME_FAMILY_STATUS is Married
# Number of missing values in NAME_FAMILY_STATUS is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of NAME_FAMILY_STATUS")                  # Set the title of the graph
percentage = df["NAME_FAMILY_STATUS"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["NAME_FAMILY_STATUS"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["NAME_FAMILY_STATUS"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# # Mojority of customers are having family Married=64.06%, 14.57% of customers are Single/Not Married, 9.77% of customers are Civil Marriage, 6.35% Separated, 5.25% are widow.

# %%
info_of_cat("OCCUPATION_TYPE") #function returns all the information required for the level 1 analysis
# Out:
# Unique values in OCCUPATION_TYPE are: ['Laborers' 'Core staff' 'Accountants' 'Managers' nan 'Drivers'
#  'Sales staff' 'Cleaning staff' 'Cooking staff' 'Private service staff'
#  'Medicine staff' 'Security staff' 'High skill tech staff'
#  'Waiters/barmen staff' 'Low-skill Laborers' 'Realty agents' 'Secretaries'
#  'IT staff' 'HR staff']
# Mode of OCCUPATION_TYPE is Laborers
# Number of missing values in OCCUPATION_TYPE is 31224
#
# There are null values in the OCCUPATION_TYPE column

# %%
mode = df["OCCUPATION_TYPE"].mode()[0]
df["OCCUPATION_TYPE"].fillna(mode, inplace = True, axis = 0)

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of OCCUPATION_TYPE")                  # Set the title of the graph
percentage = df["OCCUPATION_TYPE"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["OCCUPATION_TYPE"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["OCCUPATION_TYPE"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# # Interpretations= Majority of occupation type is Laborers with the percentage of 49.20%, Sales staff are 10.38%, corestaff are 8.95%, Managers are 6.97%, 6.06% are Drivers, 3.65% High skill tech staff, 3.26% are Accountants, 2.85% Medicine staff, 2.20% are cooking staff.

# %%
info_of_cat("APPLICATION_DAY") #function returns all the information required for the level 1 analysis
# Out:
# Unique values in APPLICATION_DAY are: ['WEDNESDAY' 'MONDAY' 'THURSDAY' 'SUNDAY' 'SATURDAY' 'FRIDAY' 'TUESDAY']
# Mode of APPLICATION_DAY is TUESDAY
# Number of missing values in APPLICATION_DAY is 0

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 7))
ax[0].set_title("Count of APPLICATION_DAY")                  # Set the title of the graph
percentage = df["APPLICATION_DAY"].value_counts()         # value_counts: returns the count of values in series: return series
labels = list(df["APPLICATION_DAY"].value_counts().index) # Converting the index of value counts into list

sns.countplot(x = df["APPLICATION_DAY"], ax = ax[0])
plt.pie(percentage,labels = labels, autopct= "%0.2f%%")  # autopct: to print the percentage on pie wedge. 2 decimal points used 

plt.show()

# %% [markdown]
# # $$\;\;\;\;\;\;Univariate \ Analysis \ of \ Continuous \ Variables$$

# %%
df
# Out:
#        SK_ID_CURR  TARGET NAME_CONTRACT_TYPE GENDER Car House  CNT_CHILDREN  \
# 0          100002       1         Cash loans      M   N     Y             0
# 1          100003       0         Cash loans      F   N     N             0
# 2          100004       0    Revolving loans      M   Y     Y             0
# 3          100006       0         Cash loans      F   N     Y             0
# 4          100007       0         Cash loans      M   N     Y             0
# ...           ...     ...                ...    ...  ..   ...           ...
# 99995      216086       0         Cash loans      F   N     Y             1
# 99996      216087       0         Cash loans      F   N     Y             1
# 99997      216088       0         Cash loans      F   Y     Y             0
# 99998      216089       0         Cash loans      F   Y     N             0
# 99999      216090       0    Revolving loans      M   Y     Y             0
#
# ...

# %% [markdown]
# a=num_df=df.select_dtypes(exclude='object')
# b=cat_df=df.select_dtypes(include='object')
# print(tabulate({"Categorical":b,"Continuous":a},headers=['Categorical','Continuous']))

# %%
def info_of_Continuous(col):
    print(f"The mean of the {col} is {df[col].mean()}")
    print(f"The median of the {col} is {df[col].median()}")
    print(f"The mode of the {col} is {df[col].mode()[0]}")
    print(f"The standard deviation of the {col} is {df[col].std()}")
    print(f"Number of missing values in the {col} is {df[col].isnull().sum()}")

# %%
info_of_Continuous('TARGET')
# Out:
# The mean of the TARGET is 0.08093
# The median of the TARGET is 0.0
# The mode of the TARGET is 0
# The standard deviation of the TARGET is 0.2727289476951945
# Number of missing values in the TARGET is 0

# %%
fig, ax = plt.subplots( figsize = (15, 7))
ax.set_title("target of customers") 
percentage = df["TARGET"].value_counts() 
labels = list(df["TARGET"].value_counts().index) 
plt.pie(percentage,labels = ['customers who pay loan on time','customer who are not paying loan on time'], autopct= "%0.2f%%") 
plt.show()

# %% [markdown]
# # Interpretation= The Majority of customers are who pays there loan on time almost 92% only 8.00% of customers who are not paying loan on time.

# %%
info_of_Continuous('CNT_CHILDREN')
# Out:
# The mean of the CNT_CHILDREN is 0.41739
# The median of the CNT_CHILDREN is 0.0
# The mode of the CNT_CHILDREN is 0
# The standard deviation of the CNT_CHILDREN is 0.7210137214425809
# Number of missing values in the CNT_CHILDREN is 0

# %%
fig, ax = plt.subplots( figsize = (15, 7))
ax.set_title("target of CNT_CHILDREN") 
percentage = df["CNT_CHILDREN"].value_counts() 
labels = list(df["CNT_CHILDREN"].value_counts().index) 
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
plt.show()

# %% [markdown]
# # Interpretation=majority of customers are not having childern 69.97%. 20.02% of customer are having 1 children, 8.59% of customers having 2 children.

# %%
info_of_Continuous('AMT_INCOME_TOTAL')
# Out:
# The mean of the AMT_INCOME_TOTAL is 169426.07027325002
# The median of the AMT_INCOME_TOTAL is 144000.0
# The mode of the AMT_INCOME_TOTAL is 135000.0
# The standard deviation of the AMT_INCOME_TOTAL is 383500.74427718896
# Number of missing values in the AMT_INCOME_TOTAL is 0

# %%
fig, ax = plt.subplots( figsize = (15, 7))
ax.set_title("target of AMT_INCOME_TOTAL") 
percentage = df["AMT_INCOME_TOTAL"].value_counts() 
labels = list(df["AMT_INCOME_TOTAL"].value_counts().index) 
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
plt.show()

# %% [markdown]
# # Interpretaton=

# %%
info_of_Continuous('AMT_CREDIT')
# Out:
# The mean of the AMT_CREDIT is 599003.4465
# The median of the AMT_CREDIT is 513040.5
# The mode of the AMT_CREDIT is 450000.0
# The standard deviation of the AMT_CREDIT is 402051.9591213264
# Number of missing values in the AMT_CREDIT is 0

# %%
def outliers(value):
    Outliers =[]
    q1 = df[value].quantile(0.25)
    q3 = df[value].quantile(0.75)
    IQR = q3 - q1
    LF = q1 - 1.5*IQR
    UF = q3 + 1.5*IQR
    
    for i in df[value]:
        if i<LF:
            Outliers.append(i)
        elif i>UF:
            Outliers.append(i)
            
    df[value] = df[value].replace(Outliers,df[value].mean())
    df[value] = df[value].fillna(df[value].mean())
    
    fig,ax = plt.subplots(1,2, figsize=(10,8))
    sns.histplot(x = df[value] ,bins =10,color = 'red',ax=ax[1])
    r1 =sns.boxplot(df[value],ax=ax[0])
    #x1 =r1['fillers'][0].get_ydata()
      
    return plt.show()

# %%
outliers('AMT_CREDIT');
# Out:
# C:\Users\ARCHIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Interpretation= The lower fence of AMT_CREDIT is 0.00 and upper fence is 1.50 There are many outliers presant.0.25% is in the majority.

# %%
info_of_Continuous('AMT_GOODS_PRICE')
# Out:
# The mean of the AMT_GOODS_PRICE is 538345.1489706662
# The median of the AMT_GOODS_PRICE is 450000.0
# The mode of the AMT_GOODS_PRICE is 450000.0
# The standard deviation of the AMT_GOODS_PRICE is 369397.7246421765
# Number of missing values in the AMT_GOODS_PRICE is 81

# %%
df['AMT_GOODS_PRICE'].mean()
# Out:
# 538345.1489706662

# %%
mean = 489199.59
df["AMT_GOODS_PRICE"].fillna(mean, axis = 0, inplace = True)

# %%
outliers('AMT_GOODS_PRICE');
# Out:
# C:\Users\ARCHIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Interpretation= the price of goods with 24k and 22k are majorily there in histogram when we replace the missing values with mean. The Mean value is 489199.59.

# %%
info_of_Continuous('DAYS_EMPLOYED')
# Out:
# The mean of the DAYS_EMPLOYED is 63292.22206
# The median of the DAYS_EMPLOYED is -1219.0
# The mode of the DAYS_EMPLOYED is 365243
# The standard deviation of the DAYS_EMPLOYED is 140839.69729599176
# Number of missing values in the DAYS_EMPLOYED is 0

# %%
fig, ax = plt.subplots(1, 2, figsize= (20, 7))               # Creating the space for the 2 images, first argument in subplots is rows and second is columns and the figure size
sns.histplot(x = df["DAYS_EMPLOYED"], ax =ax[1], color = "m") # ax[1] means image will plot at the second space
sns.boxplot(x = df["DAYS_EMPLOYED"], ax = ax[0], color = "g") # ax[0] means image will plot at the second space
plt.show()

# %%
info_of_Continuous('CNT_FAM_MEMBERS')
# Out:
# The mean of the CNT_FAM_MEMBERS is 2.1556715567155673
# The median of the CNT_FAM_MEMBERS is 2.0
# The mode of the CNT_FAM_MEMBERS is 2.0
# The standard deviation of the CNT_FAM_MEMBERS is 0.9088966556371371
# Number of missing values in the CNT_FAM_MEMBERS is 1

# %%
df['CNT_FAM_MEMBERS'].mean()
# Out:
# 2.1556715567155673

# %%
mean = 2.15
df["CNT_FAM_MEMBERS"].fillna(mean, axis = 0, inplace = True)

# %%
outliers('CNT_FAM_MEMBERS')
# Out:
# C:\Users\ARCHIT\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig, ax = plt.subplots( figsize = (15, 7))
ax.set_title("document submission of customers") 
percentage = df["CNT_FAM_MEMBERS"].value_counts() 
labels = list(df["CNT_FAM_MEMBERS"].value_counts().index) 
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
plt.show()

# %% [markdown]
# # Interpretation= The lf is 1.0 and uf is 4.0. The customers majorly having 2 members are 51.72%, 21.815 of customers having 1.0, 17.16% are having 3.0, 7.96% are having 4.0 family members.

# %%
info_of_Continuous('TOTAL_DOC_SUBMITTED')
# Out:
# The mean of the TOTAL_DOC_SUBMITTED is 0.93121
# The median of the TOTAL_DOC_SUBMITTED is 1.0
# The mode of the TOTAL_DOC_SUBMITTED is 1
# The standard deviation of the TOTAL_DOC_SUBMITTED is 0.3439173137416586
# Number of missing values in the TOTAL_DOC_SUBMITTED is 0

# %%
fig, ax = plt.subplots( figsize = (15, 7))
ax.set_title("document submission of customers") 
percentage = df["TOTAL_DOC_SUBMITTED"].value_counts() 
labels = list(df["TOTAL_DOC_SUBMITTED"].value_counts().index) 
plt.pie(percentage,labels = labels, autopct= "%0.2f%%") 
plt.show()

# %% [markdown]
# # Interpretation= Majorly customers have submitted 1 document 87.86%. and 12.14 percent of customer not submitted atleast 1 document.

# %% [markdown]
# # $$\;\;\;\;\;\;Bivariate \ Analysis \ of \ Categorical \ and \ Numerical \ Variables$$

# %% [markdown]
# CAT-CAT ANALYSIS  (relationship between categorical data)
# -----------------------------------------------------------------------------------

# %%
a=num_df=df.select_dtypes(exclude='object')
b=cat_df=df.select_dtypes(include='object')
print(tabulate({"Categorical":b,"Continuous":a},headers=['Categorical','Continuous']))
# Out:
# Categorical          Continuous
# -------------------  -------------------
# NAME_CONTRACT_TYPE   SK_ID_CURR
# GENDER               TARGET
# Car                  CNT_CHILDREN
# House                AMT_INCOME_TOTAL
# NAME_TYPE_SUITE      AMT_CREDIT
# NAME_INCOME_TYPE     AMT_GOODS_PRICE
# NAME_EDUCATION_TYPE  DAYS_EMPLOYED
# NAME_FAMILY_STATUS   MOBILE
# OCCUPATION_TYPE      WORK_PHONE
# APPLICATION_DAY      HOME_PHONE
#                      MOBILE_REACHABLE
#                      FLAG_EMAIL
#                      CNT_FAM_MEMBERS
#                      TOTAL_DOC_SUBMITTED
#                      AMT_GOODS_PRICE

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "NAME_EDUCATION_TYPE", hue = "OCCUPATION_TYPE", data = df)
plt.show()

# %% [markdown]
# # Interpretation= majority of customers having scondary/secondary special and higher education and are having a job.

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "NAME_INCOME_TYPE", hue = "OCCUPATION_TYPE", data = df)
plt.show()

# %% [markdown]
# # Interpretation=Labrores are more in the count with 17500 and having income and majorily count of customer is working.

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "House", hue = "OCCUPATION_TYPE", data = df)
plt.show()

# %% [markdown]
# # Interpretation= Majorily the customers are having a house with 35000 there are customers who are not having house are 15000.

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "GENDER", hue = "OCCUPATION_TYPE", data = df)
plt.show()

# %% [markdown]
# # Interpretation= the majority of females are more who have a occupation.

# %% [markdown]
# CAT-NUM ANALYSIS (relationship between categorical and numerical data)
# -----------------------------------------------------------------------------------------------------------

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "CNT_CHILDREN", hue = "OCCUPATION_TYPE", data = df)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "CNT_CHILDREN", hue = "NAME_INCOME_TYPE", data = df)
plt.show()

# %% [markdown]
# # Interpretation= Majority of occupied customers are not having children then some are having 1 and nobody is having more then 2 childrens

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "TARGET", hue = "NAME_INCOME_TYPE", data = df)
plt.show()

# %% [markdown]
# # Interpretation= most of the customers have other reasons there are less customers who are having a payment difficulties.

# %%
fig, ax = plt.subplots(figsize = (10, 7))
sns.countplot(x = "CNT_FAM_MEMBERS", hue = "NAME_INCOME_TYPE", data = df)
plt.show()

# %% [markdown]
# # Interpretation= moost of the working customers are having 2.0 famlily members then comercial associates, pensioner, state servant.

# %% [markdown]
# # $$\;\;\;\;\;\;Multivariate \ Analysis \ of \ Categorical \ and \ Numerical \ Variables$$

# %%
df['income'] = pd.cut(x=df['AMT_INCOME_TOTAL'], bins=[25650.0,50000,75000,100000,125000,150000,191250.0],labels=['poor','low','middle','upper middle','high ','very high'])
df_1=df[(df.TARGET == 1)]
sns.countplot(x='income',hue='TARGET',data=df_1) 
plt.show()
df_1['income'].value_counts()
# Out:
# very high       1707
# high            1344
# upper middle    1238
# middle          1134
# low              481
# poor             125
# Name: income, dtype: int64

# %% [markdown]
# # Interpretation= Target with Very High are major present in the data the poor target are very less.

# %%
df_5=df[(df.TOTAL_DOC_SUBMITTED != 0)]
sns.catplot(data=df_5,x="income",hue ='TARGET',kind="count",height=5)
df_5['income'].value_counts()
# Out:
# very high       18639
# high            14188
# upper middle    12647
# middle          11436
# low              5549
# poor             1402
# Name: income, dtype: int64

# %% [markdown]
# # Interpretation=the customers with very high income are submitted atleast one data others are not submitted atleast one data.

# %%
df_11 = df_5[(df_5.AMT_GOODS_PRICE  >= df_5.AMT_CREDIT)]

sns.catplot(data=df_11,x="income",hue ='CNT_FAM_MEMBERS',kind="count",height=5)
df_11['income'].value_counts()
# Out:
# very high       4948
# high            3979
# upper middle    3692
# middle          3386
# low             1570
# poor             399
# Name: income, dtype: int64

# %% [markdown]
# # Interpretation=Idlly customer with 2 family members are major then 1 familly member then 3 and lasltly 4 and 2.

# %%
df_15 = df[(df.AMT_INCOME_TOTAL <= 0.5*df.AMT_CREDIT)]
sns.catplot(data=df,x="income",hue ='TARGET',kind="count",height=5)
df['income'].value_counts()
# Out:
# very high       20355
# high            15670
# upper middle    14167
# middle          12908
# low              6322
# poor             1526
# Name: income, dtype: int64

# %% [markdown]
# # Interpretation=the rich customers who are having a very high income are more as compare to poor customers.
